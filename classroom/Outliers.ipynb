# %%
import pandas as pd

# %%
df1 = pd.read_csv("mpg.csv")

# %%
df2 = pd.read_csv("loans-raw.csv")

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'MPG'}>,
#         <AxesSubplot:title={'center':'Cylinders'}>,
#         <AxesSubplot:title={'center':'Engine Disp'}>],
#        [<AxesSubplot:title={'center':'Horsepower'}>,
#         <AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Accelerate'}>],
#        [<AxesSubplot:title={'center':'Year'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.distplot(df1.Accelerate)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Accelerate', ylabel='Density'>

# %%
sns.distplot(df1.Cylinders)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Cylinders', ylabel='Density'>

# %%
df1.Weight.plot.box()
# Out:
# <AxesSubplot:>

# %%
df1.boxplot("Weight")
# Out:
# <AxesSubplot:>

# %%
df1.boxplot("Weight", vert=False)
# Out:
# <AxesSubplot:>

# %%
df1.boxplot("MPG")
# Out:
# <AxesSubplot:>

# %%
df1.boxplot("MPG",by="Origin")
# Out:
# <AxesSubplot:title={'center':'MPG'}, xlabel='Origin'>

# %%
df1.boxplot("MPG",by="Cylinders")
# Out:
# <AxesSubplot:title={'center':'MPG'}, xlabel='Cylinders'>

# %%
df2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
df2.ApplicantIncome.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df2.ApplicantIncome.plot.box()
# Out:
# <AxesSubplot:>

# %%
df2.boxplot("ApplicantIncome")
# Out:
# <AxesSubplot:>

# %%
df2.boxplot("ApplicantIncome",by="Gender")
# Out:
# <AxesSubplot:title={'center':'ApplicantIncome'}, xlabel='Gender'>

# %%
def get_outliers(column,mydataframe):
    q1= mydataframe[column].quantile(0.25)
    q3 = mydataframe[column].quantile(0.75)
    iqr = q3 - q1
    maxout = q3+(1.5*iqr)
    minout = q1-(1.5*iqr)
    outliers=mydataframe[(mydataframe[column] < minout) | (mydataframe[column] > maxout)]
    without_outliers=mydataframe[(mydataframe[column] > minout) & (mydataframe[column] < maxout)]
    outlier_count=outliers.shape[0]
    return outliers, without_outliers, outlier_count

# %%
outliers, without_outliers, outlier_count = get_outliers("ApplicantIncome", df2)

# %%
outliers
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 9    LP001020    Male     Yes          1      Graduate            No
# 34   LP001100    Male      No         3+      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 67   LP001233    Male     Yes          1      Graduate            No
# 102  LP001350    male     Yes        NaN      Graduate            No
# 113  LP001350    male     Yes        NaN      Graduate            No
# 117  LP001369    male     Yes          2      Graduate            No
# 126  LP001401    male     Yes          1      Graduate            No
# 130  LP001422  Female      No          0      Graduate            No
# 137  LP001448     NaN     Yes         3+      Graduate            No
# 139  LP001451    male     Yes          1      Graduate           Yes
# 141  LP001469    male      No          0      Graduate           Yes
# 149  LP001492    male      No          0      Graduate            No
# 155  LP001508    male     Yes          2      Graduate            No
# 157  LP001516  Female     Yes          2      Graduate            No
# 166  LP001536    male     Yes         3+      Graduate            No
# 182  LP001585     NaN     Yes         3+      Graduate            No
# 194  LP001637    male     Yes          1      Graduate            No
# 196  LP001640    male     Yes          0      Graduate           Yes
# 202  LP001656    Male      No          0      Graduate            No
# 210  LP001673    Male      No          0      Graduate           Yes
# 265  LP001844    Male      No          0      Graduate           Yes
# 269  LP001859    Male     Yes          0      Graduate            No
# 282  LP001891    Male     Yes          0      Graduate            No
# 289  LP001907    Male     Yes          0      Graduate            No
# 295  LP001922    Male     Yes          0      Graduate            No
# 319  LP001996    Male      No          0      Graduate            No
# 335  LP002065    Male     Yes         3+      Graduate            No
# 344  LP002101    Male     Yes          0      Graduate           NaN
# 380  LP002191    Male     Yes          0      Graduate            No
# 381  LP002194  Female      No          0      Graduate           Yes
# 420  LP002317    Male     Yes         3+      Graduate            No
# 435  LP002364    Male     Yes          0      Graduate            No
# 443  LP002386    Male      No          0      Graduate           NaN
# 449  LP002403    Male      No          0      Graduate           Yes
# 454  LP002422    Male      No          1      Graduate            No
# 478  LP002501     NaN     Yes          0      Graduate            No
# 486  LP002527    Male     Yes          2      Graduate           Yes
# 489  LP002531    Male     Yes          1      Graduate           Yes
# 494  LP002541    Male     Yes          0      Graduate            No
# 498  LP002547    Male     Yes          1      Graduate            No
# 504  LP002582  Female      No          0  Not Graduate           Yes
# 517  LP002624    Male     Yes          0      Graduate            No
# 520  LP002634  Female      No          1      Graduate            No
# 536  LP002699    Male     Yes          2      Graduate           Yes
# 544  LP002729    Male      No          1      Graduate            No
# 545  LP002731  Female      No          0  Not Graduate           Yes
# 568  LP002795    Male     Yes         3+      Graduate           Yes
# 572  LP002813  Female     Yes          1      Graduate           Yes
# 583  LP002855    Male     Yes          2      Graduate            No
# 605  LP002938    Male     Yes          0      Graduate           Yes
# 615  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 34             12500             3000.0       320.0             360.0
# 54             11500                0.0       286.0             360.0
# 67             10750                0.0       312.0             360.0
# 102            13650                0.0         NaN             360.0
# 113            13650                0.0         NaN             360.0
# 117            11417             1126.0       225.0             360.0
# 126            14583                0.0       185.0             180.0
# 130            10408                0.0       259.0             360.0
# 137            23803                0.0       370.0             360.0
# 139            10513             3850.0       160.0             180.0
# 141            20166                0.0       650.0             480.0
# 149            14999                0.0       242.0             360.0
# 155            11757                0.0       187.0             180.0
# 157            14866                0.0        70.0             360.0
# 166            39999                0.0       600.0             180.0
# 182            51763                0.0       700.0             300.0
# 194            33846                0.0       260.0             360.0
# 196            39147             4750.0       120.0             360.0
# 202            12000                0.0       164.0             360.0
# 210            11000                0.0        83.0             360.0
# 265            16250                0.0       192.0             360.0
# 269            14683             2100.0       304.0             360.0
# 282            11146                0.0       136.0             360.0
# 289            14583                0.0       436.0             360.0
# 295            20667                0.0         NaN             360.0
# 319            20233                0.0       480.0             360.0
# 335            15000                0.0       300.0             360.0
# 344            63337                0.0       490.0             180.0
# 380            19730             5266.0       570.0             360.0
# 381            15759                0.0        55.0             360.0
# 420            81000                0.0       360.0             360.0
# 435            14880                0.0        96.0             360.0
# 443            12876                0.0       405.0             360.0
# 449            10416                0.0       187.0             360.0
# 454            37719                0.0       152.0             360.0
# 478            16692                0.0       110.0             360.0
# 486            16525             1014.0       150.0             360.0
# 489            16667             2250.0        86.0             360.0
# 494            10833                0.0       234.0             360.0
# 498            18333                0.0       500.0             360.0
# 504            17263                0.0       225.0             360.0
# 517            20833             6667.0       480.0             360.0
# 520            13262                0.0        40.0             360.0
# 536            17500                0.0       400.0             360.0
# 544            11250                0.0       196.0             360.0
# 545            18165                0.0       125.0             360.0
# 568            10139                0.0       260.0             360.0
# 572            19484                0.0       600.0             360.0
# 583            16666                0.0       275.0             360.0
# 605            16120                0.0       260.0             360.0
# 615            12000                0.0       496.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 9               1.0     Semiurban           N
# 34              1.0         Rural           N
# 54              0.0         Urban           N
# 67              1.0         Urban           Y
# 102             1.0         Urban           Y
# 113             1.0         Urban           Y
# 117             1.0         Urban           Y
# 126             1.0         Rural           Y
# 130             1.0         Urban           Y
# 137             1.0         Rural           Y
# 139             0.0         Urban           N
# 141             NaN         Urban           Y
# 149             0.0     Semiurban           N
# 155             1.0         Urban           Y
# 157             1.0         Urban           Y
# 166             0.0     Semiurban           Y
# 182             1.0         Urban           Y
# 194             1.0     Semiurban           N
# 196             1.0     Semiurban           Y
# 202             1.0     Semiurban           N
# 210             1.0         Urban           N
# 265             0.0         Urban           N
# 269             1.0         Rural           N
# 282             1.0         Urban           Y
# 289             1.0     Semiurban           Y
# 295             1.0         Rural           N
# 319             1.0         rural           N
# 335             1.0         rural           Y
# 344             1.0         Urban           Y
# 380             1.0         rural           N
# 381             1.0     Semiurban           Y
# 420             0.0         rural           N
# 435             1.0     Semiurban           Y
# 443             1.0     Semiurban           Y
# 449             0.0         Urban           N
# 454             1.0     Semiurban           Y
# 478             1.0     Semiurban           Y
# 486             1.0         rural           Y
# 489             1.0     Semiurban           Y
# 494             1.0     Semiurban           Y
# 498             1.0         Urban           N
# 504             1.0     Semiurban           Y
# 517             NaN         Urban           Y
# 520             1.0         Urban           Y
# 536             1.0         Rural           Y
# 544             NaN     Semiurban           N
# 545             1.0         Urban           Y
# 568             1.0     Semiurban           Y
# 572             1.0     Semiurban           Y
# 583             1.0         Urban           Y
# 605             1.0         Urban           Y
# 615             1.0     Semiurban           Y

# %%
without_outliers
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 620  LP002978  Female      No          0      Graduate            No
# 621  LP002979    Male     Yes         3+      Graduate            No
# 622  LP002983    Male     Yes          1      Graduate            No
# 623  LP002984    Male     Yes          2      Graduate            No
# 624  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# 1               4583             1508.0       128.0             360.0
# 2               3000                0.0        66.0             360.0
# 3               2583             2358.0       120.0             360.0
# 4               6000                0.0       141.0             360.0
# ..               ...                ...         ...               ...
# 620             2900                0.0        71.0             360.0
# 621             4106                0.0        40.0             180.0
# 622             8072              240.0       253.0             360.0
# 623             7583                0.0       187.0             360.0
# 624             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 620             1.0         Rural           Y
# 621             1.0         Rural           Y
# 622             1.0         Urban           Y
# 623             1.0         Urban           Y
# 624             0.0     Semiurban           N
#
# [573 rows x 13 columns]

# %%
outlier_count
# Out:
# 52
